# %% [markdown]
# # fetch_olivetti_facesを使って顔識別を行う

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.utils import np_utils
from sklearn.datasets import fetch_olivetti_faces
from sklearn.model_selection import train_test_split

# %%
faces = fetch_olivetti_faces()

# %%
x = faces.images
y = faces.target

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=10)

# %%
X_train = X_train.reshape(320,4096) / 255
X_test = X_test.reshape(80,4096) / 255

# %%
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
model = Sequential([
        Dense(512, input_shape=(4096,)),
        Activation('sigmoid'),
        Dense(40),
        Activation('softmax')
    ])

# %%
# 損失関数、 最適化アルゴリズムなどを設定しモデルのコンパイルを行う
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
# 学習処理の実行
history = model.fit(X_train, y_train, batch_size=10, verbose=1, epochs=20, validation_split=0.1)
# Out:
# Train on 288 samples, validate on 32 samples
# Epoch 1/20
# 288/288 [==============================] - 1s 2ms/step - loss: 3.7269 - accuracy: 0.0208 - val_loss: 3.8215 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7255 - accuracy: 0.0174 - val_loss: 3.8055 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 288/288 [==============================] - 0s 970us/step - loss: 3.7309 - accuracy: 0.0139 - val_loss: 3.8043 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 288/288 [==============================] - 0s 950us/step - loss: 3.7273 - accuracy: 0.0174 - val_loss: 3.7843 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7281 - accuracy: 0.0208 - val_loss: 3.7886 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7282 - accuracy: 0.0208 - val_loss: 3.7932 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7238 - accuracy: 0.0139 - val_loss: 3.7831 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7279 - accuracy: 0.0069 - val_loss: 3.7812 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7278 - accuracy: 0.0278 - val_loss: 3.7875 - val_accuracy: 0.0312
# Epoch 10/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7290 - accuracy: 0.0174 - val_loss: 3.7902 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7236 - accuracy: 0.0208 - val_loss: 3.8047 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7271 - accuracy: 0.0174 - val_loss: 3.8028 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7269 - accuracy: 0.0243 - val_loss: 3.7869 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 288/288 [==============================] - 0s 2ms/step - loss: 3.7284 - accuracy: 0.0104 - val_loss: 3.7772 - val_accuracy: 0.0312
# Epoch 15/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7294 - accuracy: 0.0035 - val_loss: 3.7731 - val_accuracy: 0.0312
# Epoch 16/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7297 - accuracy: 0.0139 - val_loss: 3.7813 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7308 - accuracy: 0.0174 - val_loss: 3.7855 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7269 - accuracy: 0.0208 - val_loss: 3.7947 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 288/288 [==============================] - 0s 2ms/step - loss: 3.7311 - accuracy: 0.0104 - val_loss: 3.8042 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 288/288 [==============================] - 0s 1ms/step - loss: 3.7297 - accuracy: 0.0174 - val_loss: 3.8024 - val_accuracy: 0.0312

# %%
# 予測
score = model.evaluate(X_test, y_test, verbose=1)
print('test accuracy : ', score[1])
# Out:
# 80/80 [==============================] - 0s 329us/step
# test accuracy :  0.0

# %% [markdown]
# ## グラフ作成

# %%
import matplotlib.pyplot as plt

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# lossのグラフ
plt.plot(range(20), loss, marker='.', label='loss')
plt.plot(range(20), val_loss, marker='.', label='val_loss')
plt.legend(loc='best', fontsize=10)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# %%
# accuracyのグラフ
plt.plot(range(20), acc, marker='.', label='acc')
plt.plot(range(20), val_acc, marker='.', label='val_acc')
plt.legend(loc='best', fontsize=10)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.show()
